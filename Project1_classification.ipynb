# %%
import pandas

from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

names = ['temperature', 'rainfall','cities']

# %%
data = pandas.read_csv('/Users/yuhongluo/Desktop/project12.csv',names = names)

# %%
print (type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(data.shape)
# Out:
# (285, 3)

# %%
print(data.head(20))
# Out:
#     temperature  rainfall cities
# 0          44.4      4.84    NYC
# 1          47.8      4.23    NYC
# 2          36.4      3.57    NYC
# 3          40.4      3.49    NYC
# 4          35.6      5.01    NYC
# 5          42.5      3.08    NYC
# 6          41.4      2.38    NYC
# 7          37.8      3.57    NYC
# 8          43.0      1.02    NYC
# 9          34.7      3.33    NYC
# 10         37.6      7.70    NYC
# 11         44.8      6.47    NYC
# 12         36.5      4.74    NYC
# 13         36.8      1.25    NYC
# 14         32.4      3.70    NYC
# 15         39.3      4.46    NYC
# 16         42.1      1.67    NYC
# 17         43.3      5.96    NYC
# 18         39.9      4.75    NYC
# 19         48.4      2.88    NYC

# %%
print(data.describe())
# Out:
#        temperature    rainfall
# count   285.000000  285.000000
# mean     51.460351    2.794807
# std       8.005082    1.983576
# min      32.400000    0.000000
# 25%      43.400000    1.140000
# 50%      54.500000    2.490000
# 75%      57.800000    4.070000
# max      64.300000   10.540000

# %%
print(data.groupby('cities').size())
# Out:
# cities
# NYC    95
# SD     95
# SJ     95
# dtype: int64

# %%
plt.figure(figsize=(8,4),dpi=288)
data.plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False)
plt.show()

# %%
data.hist()
plt.show()

# %%
scatter_matrix(data)
plt.show()

# %%
data.plot(kind="scatter", x="temperature", y="rainfall")

# %%
sns.FacetGrid(data, hue="cities", size=6) \
   .map(plt.scatter, "temperature", "rainfall") \
   .add_legend()
# Out:
# /Users/yuhongluo/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(x="cities", y="rainfall", data=data)

# %%
ax = sns.boxplot(x="cities", y="temperature", data=data)
ax = sns.stripplot(x="cities", y="temperature", data=data, jitter=True, edgecolor="gray")

# %%
sns.FacetGrid(data, hue="cities", size=6) \
   .map(sns.kdeplot, "temperature") \
   .add_legend()
# Out:
# /Users/yuhongluo/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(data, hue="cities", size=3)
# Out:
# /Users/yuhongluo/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(data, kind="reg", size=3)

# %%
sns.pairplot(data, hue="cities", kind="reg", size=3)
